# %%
import pandas as pd

# %%
df = pd.read_csv(r'd:\Startup\Project\ai-career-coach\data\processed\top_skill_by_role_cleaned.csv')
print(df.head())
# Out:
#   Standardized_Job_Title               Skill  Count
# 0              Analytics               excel     19
# 1              Analytics  data visualization     16
# 2              Analytics            power bi     16
# 3              Analytics              python     16
# 4              Analytics                 sql     15

# %%
skills = df['Skill'].values
print(skills)
# Out:
# ['excel' 'data visualization' 'power bi' 'python' 'sql' 'tableau'
#  'statistics' 'azure' 'etl' 'leadership' 'excel' 'business analysis'
#  'leadership' 'llm' 'presentation' 'market research' 'power bi' 'python'
#  'sql' 'statistics' 'data visualization' 'sql' 'python' 'power bi'
#  'tableau' 'excel' 'r' 'statistics' 'etl' 'pandas' 'etl' 'sql' 'python'
#  'airflow' 'spark' 'aws' 'azure' 'dbt' 'gcp' 'snowflake' 'python' 'sql'
#  'statistics' 'data visualization' 'tensorflow' 'aws' 'numpy' 'pandas'
#  'spark' 'data preprocessing' 'python' 'pytorch' 'tensorflow' 'nlp' 'llm'
#  'statistics' 'artificial intelligence' 'aws' 'azure' 'gcp' 'big data'
#  'data visualization' 'sql' 'aws' 'etl' 'power bi' 'dashboarding' 'python'
#  'snowflake' 'excel' 'python' 'data visualization' 'r' 'sql' 'excel'
#  'power bi' 'tableau' 'big data' 'dashboarding' 'market research']

# %%
unique_skills = set(skills)
print(unique_skills)
# Out:
# {'big data', 'presentation', 'power bi', 'r', 'excel', 'data visualization', 'spark', 'tensorflow', 'artificial intelligence', 'market research', 'statistics', 'snowflake', 'data preprocessing', 'business analysis', 'dashboarding', 'sql', 'nlp', 'tableau', 'gcp', 'python', 'numpy', 'pandas', 'aws', 'airflow', 'llm', 'leadership', 'azure', 'pytorch', 'etl', 'dbt'}
